# %%
import pandas as pd
students = pd.DataFrame({
    "id":[1,2,3],
    "name":["Abishek","arshik","jina"]

})
marks = pd.DataFrame({
    "id":[1,2,3],
    "maths":[90,98,97]

})

mark = pd.DataFrame({
    "id":[1,2,3],
    "tamil":[90,90,90]
})
mar = pd.DataFrame({
    "id":[1,2,3],
    "science":[80,70,100]
})
result = pd.merge(students,marks,on="id")
print(result)
# Out:
#    id     name  maths
# 0   1  Abishek     90
# 1   2   arshik     98
# 2   3     jina     97
