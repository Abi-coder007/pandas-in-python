# %%
#  Data frame
import pandas as pd

data = {
    "Name": ["Abishek", "Rahul", "sbuhn"],
    "Age": [19, 20, 21]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age
# 0  Abishek   19
# 1    Rahul   20
# 2    sbuhn   21

# %%
car = {
    "name":["dodge","maruthi","honda"],
    "power":[100,100,100]
}
df = pd.DataFrame(car)
print(df)
# Out:
#       name  power
# 0    dodge    100
# 1  maruthi    100
# 2    honda    100
