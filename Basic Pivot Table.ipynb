# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["abishek","sajin","stepen","aswin","arshik"],
    "subject": ["maths","maths","english","english","maths"],
    "marks": [56,67,98,90,77]
})

# %%
df.pivot_table(values="marks", index="subject", aggfunc="mean")
# Out:
#              marks
# subject
# english  94.000000
# maths    66.666667
